# %%
import smtplib

# %%
mail_sender = smtplib.SMTP('smtp.gmail.com',587)

# %%
mail_sender.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
mail_sender.login('vijay262005@gmail.com','uvie aryo kxhn spmk')
# Out:
# (235, b'2.7.0 Accepted')

# %%
msg = "Here are your job matches for the day!"
mail_sender.sendmail('vijay262005@gmail.com','vijay262005@gmail.com',msg)
# Out:
# {}

# %%
mail_sender.quit()
# Out:
# (221,
#  b'2.0.0 closing connection d2e1a72fcca58-84564d8a7f0sm3480093b3a.13 - gsmtp')
